# %%
import numpy as np
import pandas as pd

# %%
datas = np.random.normal(0,1, (300, 400))

# %%
datas.shape
# Out:
# (300, 400)

# %%
data_pd = pd.DataFrame(datas)

# %%
_index = ("股票" + str(i) for i in range(datas.shape[0]))
_column = pd.date_range("2001-12-12", periods=datas.shape[1], freq="B")
data_pd = pd.DataFrame(datas, index=_index, columns=_column)

# %%
data_pd
# Out:
#        2001-12-12  2001-12-13  2001-12-14  2001-12-17  2001-12-18  2001-12-19  \
# 股票0     -0.022493   -0.953210    1.205576   -0.826415    0.085668    0.942993
# 股票1     -1.320176   -1.319189   -0.523711    0.488407   -1.669576    0.061892
# 股票2      1.493534   -1.339481    1.462397   -0.322199    0.490999   -0.107603
# 股票3      0.801650    0.925214   -1.148588   -2.036336   -1.518156   -0.850927
# 股票4     -0.871426   -0.430177    0.833301   -0.672575   -0.541489    0.803864
# 股票5      0.167537   -0.402977    0.778770   -0.468721    0.611880    0.576908
# 股票6     -1.043773   -0.815559    0.569097   -1.513961    0.570347    1.644868
# 股票7     -1.124119   -0.416927   -0.292639   -1.263094   -1.243712    1.197011
# 股票8      1.815292    0.398335    0.706692   -0.220886    0.236624    0.988489
# 股票9     -0.353033    0.704427   -0.573890   -0.648917    1.921079    0.770745
# 股票10    -0.960924    0.154378    0.202498    0.279332    0.446205   -0.294055
# ...

# %%
# Out:
#                  股票0       股票1       股票2       股票3       股票4       股票5  \
# 2001-12-12 -0.022493 -1.320176  1.493534  0.801650 -0.871426  0.167537
# 2001-12-13 -0.953210 -1.319189 -1.339481  0.925214 -0.430177 -0.402977
# 2001-12-14  1.205576 -0.523711  1.462397 -1.148588  0.833301  0.778770
# 2001-12-17 -0.826415  0.488407 -0.322199 -2.036336 -0.672575 -0.468721
# 2001-12-18  0.085668 -1.669576  0.490999 -1.518156 -0.541489  0.611880
# 2001-12-19  0.942993  0.061892 -0.107603 -0.850927  0.803864  0.576908
# 2001-12-20 -0.700141 -0.061217  0.010308  1.620191  1.812130 -1.423218
# 2001-12-21 -0.540706 -0.067235 -0.633780 -0.029073 -1.097732 -1.956144
# 2001-12-24  0.644668  1.376721 -0.158806 -1.149190  0.015845 -1.007886
# 2001-12-25  0.281528 -0.817059 -0.888935 -0.820720 -1.402598 -1.586378
# 2001-12-26  0.405670 -0.228880  1.515743  0.509048  0.935332  2.362709
# 2001-12-27 -1.233316 -0.006259 -0.985448  0.639266  1.622637 -1.638307
# ...
