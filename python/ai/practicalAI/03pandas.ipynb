# %%
import pandas as pd

# %%
df = pd.read_csv("titanic/train.csv", header=0)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df["Age"].hist()

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Name"].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df[df["Sex"] == "female"].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.sort_values("Age", ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
survived_group = df.groupby("Survived")
survived_group.mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
survived_group.max()
# Out:
#           PassengerId  Pclass                         Name   Sex   Age  SibSp  \
# Survived
# 0                 891       3  van Melkebeke, Mr. Philemon  male  74.0      8
# 1                 890       3      de Mulder, Mr. Theodore  male  80.0      4
#
#           Parch     Ticket      Fare
# Survived
# 0             6  WE/P 5735  263.0000
# 1             5  WE/P 5735  512.3292

# %%
survived_group.count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %%
df.iloc[851,:]
# Out:
# PassengerId                    852
# Survived                         0
# Pclass                           3
# Name           Svensson, Mr. Johan
# Sex                           male
# Age                             74
# SibSp                            0
# Parch                            0
# Ticket                      347060
# Fare                         7.775
# Cabin                          NaN
# Embarked                         S
# Name: 851, dtype: object

# %%
df.iloc[0,3]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df.loc[851]
# Out:
# PassengerId                    852
# Survived                         0
# Pclass                           3
# Name           Svensson, Mr. Johan
# Sex                           male
# Age                             74
# SibSp                            0
# Parch                            0
# Ticket                      347060
# Fare                         7.775
# Cabin                          NaN
# Embarked                         S
# Name: 851, dtype: object

# %%
# 查看含有至少一个NaN值的数据
df[pd.isnull(df).any(axis=1)].head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %%
df[pd.isnull(df).any(axis=1)].head()
# Out:
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# <ipython-input-57-b326d61f0379> in <module>
# ----> 1 df[not (pd.isnull(df).any(axis=1))].head()
#
# ~/.virtualenvs/pytorch/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# 删除含有NaN值的数据行
df = df.dropna() # 删除含有NaN值的行
df = df.reset_index() # 重置行的索引
df.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      1            2         1       1
# 1      3            4         1       1
# 2      6            7         0       1
# 3     10           11         1       3
# 4     11           12         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                            McCarthy, Mr. Timothy J    male  54.0      0
# 3                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 4                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 0      0  PC 17599  71.2833   C85        C
# 1      0    113803  53.1000  C123        S
# 2      0     17463  51.8625   E46        S
# 3      1   PP 9549  16.7000    G6        S
# 4      0    113783  26.5500  C103        S

# %%
# 删除多列
df = df.drop(["Name", "Cabin", "Ticket"], axis=1) # 暂时不需要类型为文本的数据条目
df.head()
# Out:
#    index  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0      1            2         1       1  female  38.0      1      0  71.2833
# 1      3            4         1       1  female  35.0      1      0  53.1000
# 2      6            7         0       1    male  54.0      0      0  51.8625
# 3     10           11         1       3  female   4.0      1      1  16.7000
# 4     11           12         1       1  female  58.0      0      0  26.5500
#
#   Embarked
# 0        C
# 1        S
# 2        S
# 3        S
# 4        S

# %%
df["family_size"] = df.apply(lambda x: x["SibSp"] + x["Parch"], axis=1)

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0        1            2         1       1  female  38.0      1      0
# 1        3            4         1       1  female  35.0      1      0
# 2        6            7         0       1    male  54.0      0      0
# 3       10           11         1       3  female   4.0      1      1
# 4       11           12         1       1  female  58.0      0      0
# ..     ...          ...       ...     ...     ...   ...    ...    ...
# 178    871          872         1       1  female  47.0      1      1
# 179    872          873         0       1    male  33.0      0      0
# 180    879          880         1       1  female  56.0      0      1
# 181    887          888         1       1  female  19.0      0      0
# 182    889          890         1       1    male  26.0      0      0
#
#         Fare Embarked  family_size
# 0    71.2833        C            1
# 1    53.1000        S            1
# 2    51.8625        S            0
# 3    16.7000        S            2
# 4    26.5500        S            0
# ..       ...      ...          ...
# 178  52.5542        S            2
# 179   5.0000        S            0
# 180  83.1583        C            1
# 181  30.0000        S            0
# 182  30.0000        C            0
#
# [183 rows x 11 columns]

# %%
df = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'family_size', 'Fare', 'Embarked', 'Survived']]
df.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch  family_size     Fare Embarked  Survived
# 0       1  female  38.0      1      0            1  71.2833        C         1
# 1       1  female  35.0      1      0            1  53.1000        S         1
# 2       1    male  54.0      0      0            0  51.8625        S         0
# 3       3  female   4.0      1      1            2  16.7000        S         1
# 4       1  female  58.0      0      0            0  26.5500        S         1

# %%
df.to_csv("processed_titanic.csv", index=False)

# %%
ls
# Out:
# 02numpy.ipynb  03pandas.ipynb  processed_titanic.csv  titanic/
